# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from PIL import Image  # Added Image import

# Paths
img_size = 128
batch_size = 32
dataset_path = os.path.join(os.getcwd(), 'C:\\Users\\DELL\\Downloads\\archive\\brain_tumor_dataset')

# Data generator
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_data = datagen.flow_from_directory(dataset_path, target_size=(img_size, img_size), batch_size=batch_size, class_mode='binary', subset='training')
val_data = datagen.flow_from_directory(dataset_path, target_size=(img_size, img_size), batch_size=batch_size, class_mode='binary', subset='validation')

# Build Simple CNN Model
model = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(img_size, img_size, 3)),
    MaxPooling2D(2, 2),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_data, validation_data=val_data, epochs=20)

# Save the model in the recommended .keras format
model.save("model.keras")


# Provide a download link for the model
FileLink("model.keras")
# Out:
# Found 203 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 305ms/step - accuracy: 0.6206 - loss: 0.8677 - val_accuracy: 0.7400 - val_loss: 0.5683
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 181ms/step - accuracy: 0.7057 - loss: 0.5823 - val_accuracy: 0.7400 - val_loss: 0.5282
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - accuracy: 0.8183 - loss: 0.4715 - val_accuracy: 0.7400 - val_loss: 0.5485
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.7491 - loss: 0.5336 - val_accuracy: 0.7800 - val_loss: 0.5418
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - accuracy: 0.7777 - loss: 0.4845 - val_accuracy: 0.7800 - val_loss: 0.4876
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - accuracy: 0.8869 - loss: 0.3535 - val_accuracy: 0.7400 - val_loss: 0.5091
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - accuracy: 0.8989 - loss: 0.3106 - val_accuracy: 0.7800 - val_loss: 0.4886
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 222ms/step - accuracy: 0.8930 - loss: 0.2783 - val_accuracy: 0.8000 - val_loss: 0.4299
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - accuracy: 0.8725 - loss: 0.2730 - val_accuracy: 0.8000 - val_loss: 0.4806
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.8723 - loss: 0.2680 - val_accuracy: 0.8200 - val_loss: 0.4257
# Epoch 11/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 0.9036 - loss: 0.2490 - val_accuracy: 0.7800 - val_loss: 0.4927
# Epoch 12/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.9612 - loss: 0.1125 - val_accuracy: 0.8800 - val_loss: 0.3946
# Epoch 13/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - accuracy: 0.9585 - loss: 0.1057 - val_accuracy: 0.8000 - val_loss: 0.4984
# Epoch 14/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 0.9417 - loss: 0.1408 - val_accuracy: 0.8000 - val_loss: 0.4196
# Epoch 15/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - accuracy: 0.9786 - loss: 0.0992 - val_accuracy: 0.8200 - val_loss: 0.4577
# Epoch 16/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - accuracy: 1.0000 - loss: 0.0617 - val_accuracy: 0.8000 - val_loss: 0.5566
# Epoch 17/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 0.9717 - loss: 0.0743 - val_accuracy: 0.8800 - val_loss: 0.4631
# Epoch 18/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step - accuracy: 0.9918 - loss: 0.0581 - val_accuracy: 0.8000 - val_loss: 0.5288
# Epoch 19/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - accuracy: 0.9938 - loss: 0.0520 - val_accuracy: 0.8800 - val_loss: 0.4783
# Epoch 20/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.9918 - loss: 0.0407 - val_accuracy: 0.8600 - val_loss: 0.4948
# C:\Users\DELL\model.keras
